# %%
import pandas as pd
import numpy as np


from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV


from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
raw_data_15 = pd.read_csv(r"Seasons\season14-15.csv")
raw_data_15['Season']=2014
raw_data_16 = pd.read_csv(r"Seasons\season15-16.csv")
raw_data_16['Season']=2015
raw_data_17 = pd.read_csv(r"Seasons\season16-17.csv")
raw_data_17['Season']=2016
raw_data_18 = pd.read_csv(r"Seasons\season17-18.csv")
raw_data_18['Season']=2017
raw_data_19 = pd.read_csv(r"Seasons\season18-19.csv")
raw_data_19['Season']=2018
EA_features=pd.read_csv("EA_rating15-20.csv") # need it put this within the dataframe
frames=[raw_data_15,raw_data_16,raw_data_17,raw_data_18,raw_data_19]
data=pd.concat(frames).reset_index()

cols_to_consider = ['Season','Date','home_encoded', 'away_encoded',
                'FTHG','FTAG','HTHG', 'HTAG', 'HS',
                'AS', 'HST', 'AST', 'HC','AC','HTR','FTR']

data=data.replace({'H':1,'D':2,'A':0})

data['Date']=pd.to_datetime(data['Date'],dayfirst='True')
data.drop(['Div'],axis=1,inplace=True)

encoder = LabelEncoder()
home_encoded = encoder.fit_transform(data['HomeTeam'])
home_encoded_mapping = dict(
    zip(encoder.classes_, encoder.transform(encoder.classes_).tolist()))
data['home_encoded'] = home_encoded

away_encoded = encoder.fit_transform(data['AwayTeam'])
away_encoded_mapping = dict(
    zip(encoder.classes_, encoder.transform(encoder.classes_).tolist()))
data['away_encoded'] = away_encoded


data=data[cols_to_consider]
EA_features.drop(['index'],axis=1,inplace=True)
data=data.merge(EA_features, left_on=['home_encoded','Season'], right_on=['Club','Release_year'],suffixes=(False, False))
data=data.merge(EA_features, left_on=['away_encoded','Season'], right_on=['Club','Release_year'],suffixes=('_home', '_away'))

data['dif_Overall']=data['Overall_home']-data['Overall_away']
data['dif_Physical']=data['Physical_home']-data['Physical_away']
data['dif_Defending']=data['Defending_home']-data['Defending_away']
data['dif_Pace']=data['Pace_home']-data['Pace_away']
data['dif_Shooting']=data['Shooting_home']-data['Shooting_away']
data['dif_Passing']=data['Passing_home']-data['Passing_away']
data['dif_Dribbling']=data['Dribbling_home']-data['Dribbling_away']
data['dif_GK_diving']=data['GK_diving_home']-data['GK_diving_away']

data.drop(columns=[       'Release_year_home', 'Club_home', 'Overall_home', 'Physical_home',
       'Defending_home', 'Pace_home', 'Shooting_home', 'Passing_home',
       'Dribbling_home', 'GK_diving_home', 'Release_year_away', 'Club_away',
       'Overall_away', 'Physical_away', 'Defending_away', 'Pace_away',
       'Shooting_away', 'Passing_away', 'Dribbling_away', 'GK_diving_away','Season'],inplace=True)

data=data.sort_values(by='Date')

# %%
def average_season(string):
    stats=[]
    for i, j in zip(data["Date"],data['home_encoded']):
        oi = data.loc[data["Date"]<i]
        oi = oi.loc[oi["home_encoded"]==j]
        oi = oi[string].mean()
        stats.append(oi)

    data["avg_"+string] = pd.DataFrame(np.array(stats))
        
def average_last_3(variable):
    stats = []
    for i, j in zip(data["Date"],data["home_encoded"]):
        oi = data.loc[data["Date"]<i]
        oi = oi.loc[oi["home_encoded"]==j]
        oi= oi.reset_index(drop=True)
        oi = oi[-3:]
        oi = oi[variable].mean()
        stats.append(oi)

    data["last_3_avg_"+variable] = pd.DataFrame(np.array(stats))    
    
def sequence_5():
    sequences = []
    for i, j in zip(data["Date"],data["home_encoded"]):
        oi = data.loc[data["Date"]<i]
        oi = oi.loc[oi["home_encoded"]==j]
        oi= oi.reset_index(drop=True)
        oi = oi[-5:]
        di = {1:3,
             2:1,
             0:0}
        oi = oi.replace({"FTR":di})
        oi = oi.FTR.sum()
        sequences.append(oi)
    data["pnts_lst_5"] = pd.DataFrame(np.array(sequences))
    
def sequence_3():
    sequences = []
    for i, j in zip(data["Date"],data["home_encoded"]):
        oi = data.loc[data["Date"]<i]
        oi = oi.loc[oi["home_encoded"]==j]
        oi= oi.reset_index(drop=True)
        oi = oi[-3:]
        di = {1:3,
             2:1,
             0:0}
        oi = oi.replace({"FTR":di})
        oi = oi.FTR.sum()
        sequences.append(oi)
    data["pnts_lst_3"] = pd.DataFrame(np.array(sequences))
    
    
def sequence_1():

    sequences = []
    for i, j in zip(data["Date"],data["home_encoded"]):
        oi = data.loc[data["Date"]<i]
        oi = oi.loc[oi["home_encoded"]==j]
        oi= oi.reset_index(drop=True)
        oi = oi[-1:]
        di = {1:3,
             2:1,
             0:0}
        oi = oi.replace({"FTR":di})
        oi = oi.FTR.sum()
        sequences.append(oi)
    data["pnts_lst_game"] = pd.DataFrame(np.array(sequences))

# %%
stats_average = data.drop(columns=['Date','home_encoded', 'away_encoded', 'FTR',
                                    'dif_Overall', 'dif_Physical', 'dif_Defending', 'dif_Pace',
                                   'dif_Shooting', 'dif_Passing', 'dif_Dribbling', 'dif_GK_diving'])

for i in stats_average.columns:
    average_season(i)
    average_last_3(i)
    
sequence_5()
sequence_3()
sequence_1()

# %%
X=data.drop(['Date','FTHG', 'FTAG', 'HTHG','HTAG', 'HS',
             'AS', 'HST', 'AST', 'HC', 'AC', 'HTR', 'FTR'],axis=1)

X.fillna(0,inplace=True)
y=data['FTR']# change for want is wanted

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=35).fit(X_scaled)
X_pca = pca.transform(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)')
plt.show()
# X.to_csv('X-20.csv',index=False)

# %%
svc_classifier = SVC(random_state=100, kernel='rbf')
lr_classifier = LogisticRegression(multi_class='ovr', max_iter=500)
nbClassifier = GaussianNB()
dtClassifier = DecisionTreeClassifier()
rfClassifier = RandomForestClassifier()

X_train, X_test, Y_train, Y_test = train_test_split(X_pca, y,test_size=0.3,random_state=4,shuffle=None)#

# %% [markdown]
# # NB

# %%
nb_classifier = GaussianNB()

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gs_NB = GridSearchCV(estimator=nb_classifier, 
                 param_grid=params_NB, 
                 verbose=1, 
                cv=10, n_jobs=-1) 
gs_NB.fit(X_train, Y_train)

print(gs_NB.best_params_)
print("-" * 100)
print(gs_NB.best_estimator_)
print("-" * 100)


Y_rf = gs_NB.predict(X_test)
F=classification_report(Y_test, Y_rf)
print(F)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:   11.1s
# {'var_smoothing': 0.2848035868435802}
# ----------------------------------------------------------------------------------------------------
# GaussianNB(var_smoothing=0.2848035868435802)
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.33      0.43       111
#            1       0.50      0.91      0.64       169
#            2       1.00      0.02      0.04        91
#
#     accuracy                           0.52       371
#    macro avg       0.70      0.42      0.37       371
# weighted avg       0.65      0.52      0.43       371
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   12.9s finished

# %% [markdown]
# # LR

# %%
lr_classifier = LogisticRegression()
param_lr = {"C":[100,25, 10, 1.0, 0.1, 0.01], "penalty":["l1","l2"],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
             }


gs_LR = LogisticRegression()
gs_LR = GridSearchCV(lr_classifier, param_grid=param_lr, refit = True, verbose = 3, cv=10) 
gs_LR.fit(X_train, Y_train)
print(gs_LR.best_params_)
print("-" * 100)
print(gs_LR.best_estimator_)
print("-" * 100)

Y_rf = gs_LR.predict(X_test)
Z=classification_report(Y_test, Y_rf)
print(Z)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=newton-cg .............................
# [CV] ... C=100, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=100, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.598, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.453, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] . C=100, penalty=l1, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=sag ...................................
# [CV] ......... C=100, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.471, total=   0.2s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.540, total=   0.2s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.598, total=   0.1s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.414, total=   0.1s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.494, total=   0.1s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.453, total=   0.1s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.581, total=   0.1s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.465, total=   0.2s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.512, total=   0.2s
# [CV] C=100, penalty=l1, solver=saga ..................................
# [CV] ...... C=100, penalty=l1, solver=saga, score=0.500, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.471, total=   0.0s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.540, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.598, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.414, total=   0.0s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.494, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.453, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.581, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.465, total=   0.0s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.512, total=   0.1s
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] . C=100, penalty=l2, solver=newton-cg, score=0.500, total=   0.1s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.471, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.540, total=   0.1s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.598, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.414, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.494, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.453, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.581, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.465, total=   0.1s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.512, total=   0.0s
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ..... C=100, penalty=l2, solver=lbfgs, score=0.500, total=   0.1s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.598, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.453, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.453, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=100, penalty=l2, solver=liblinear .............................
# [CV] . C=100, penalty=l2, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.471, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.540, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.598, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.414, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.494, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.453, total=   0.1s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.581, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.465, total=   0.1s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.512, total=   0.0s
# [CV] C=100, penalty=l2, solver=sag ...................................
# [CV] ....... C=100, penalty=l2, solver=sag, score=0.500, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.471, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.540, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.598, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.414, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.494, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.453, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.581, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.465, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.512, total=   0.1s
# [CV] C=100, penalty=l2, solver=saga ..................................
# [CV] ...... C=100, penalty=l2, solver=saga, score=0.500, total=   0.1s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=25, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=25, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.598, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=25, penalty=l1, solver=liblinear ..............................
# [CV] .. C=25, penalty=l1, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=sag ....................................
# [CV] .......... C=25, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.471, total=   0.1s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.540, total=   0.2s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.598, total=   0.2s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.414, total=   0.1s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.494, total=   0.1s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.453, total=   0.2s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.581, total=   0.1s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.465, total=   0.2s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.523, total=   0.2s
# [CV] C=25, penalty=l1, solver=saga ...................................
# [CV] ....... C=25, penalty=l1, solver=saga, score=0.500, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.471, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.540, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.598, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.414, total=   0.0s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.494, total=   0.0s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.453, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.581, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.465, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.512, total=   0.1s
# [CV] C=25, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=25, penalty=l2, solver=newton-cg, score=0.500, total=   0.1s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.471, total=   0.1s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.540, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.598, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.414, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.494, total=   0.1s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.453, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.581, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.465, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.512, total=   0.0s
# [CV] C=25, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=25, penalty=l2, solver=lbfgs, score=0.500, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.598, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.453, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=25, penalty=l2, solver=liblinear ..............................
# [CV] .. C=25, penalty=l2, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.471, total=   0.1s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.540, total=   0.1s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.598, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.414, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.494, total=   0.1s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.453, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.581, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.465, total=   0.0s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.512, total=   0.1s
# [CV] C=25, penalty=l2, solver=sag ....................................
# [CV] ........ C=25, penalty=l2, solver=sag, score=0.500, total=   0.0s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.471, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.540, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.598, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.414, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.494, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.453, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.581, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.465, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.512, total=   0.1s
# [CV] C=25, penalty=l2, solver=saga ...................................
# [CV] ....... C=25, penalty=l2, solver=saga, score=0.500, total=   0.1s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=newton-cg ..............................
# [CV] .... C=10, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=lbfgs ..................................
# [CV] ........ C=10, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.586, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=10, penalty=l1, solver=liblinear ..............................
# [CV] .. C=10, penalty=l1, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=sag ....................................
# [CV] .......... C=10, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.483, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.540, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.598, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.414, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.494, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.453, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.581, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.477, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.523, total=   0.2s
# [CV] C=10, penalty=l1, solver=saga ...................................
# [CV] ....... C=10, penalty=l1, solver=saga, score=0.500, total=   0.2s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.471, total=   0.0s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.540, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.598, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.414, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.494, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.453, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.581, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.465, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.523, total=   0.1s
# [CV] C=10, penalty=l2, solver=newton-cg ..............................
# [CV] .. C=10, penalty=l2, solver=newton-cg, score=0.500, total=   0.1s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.471, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.540, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.598, total=   0.1s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.414, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.494, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.453, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.581, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.465, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.523, total=   0.0s
# [CV] C=10, penalty=l2, solver=lbfgs ..................................
# [CV] ...... C=10, penalty=l2, solver=lbfgs, score=0.500, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.483, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.598, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.402, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.593, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=10, penalty=l2, solver=liblinear ..............................
# [CV] .. C=10, penalty=l2, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.471, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.540, total=   0.1s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.598, total=   0.1s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.414, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.494, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.453, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.581, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.465, total=   0.1s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.523, total=   0.0s
# [CV] C=10, penalty=l2, solver=sag ....................................
# [CV] ........ C=10, penalty=l2, solver=sag, score=0.500, total=   0.0s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.471, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.540, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.598, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.414, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.494, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.453, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.581, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.465, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.523, total=   0.1s
# [CV] C=10, penalty=l2, solver=saga ...................................
# [CV] ....... C=10, penalty=l2, solver=saga, score=0.500, total=   0.1s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=newton-cg .............................
# [CV] ... C=1.0, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=lbfgs .................................
# [CV] ....... C=1.0, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.540, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.586, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.448, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.517, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.465, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.605, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.477, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=liblinear .............................
# [CV] . C=1.0, penalty=l1, solver=liblinear, score=0.547, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# [CV] ......... C=1.0, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# [CV] ......... C=1.0, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# [CV] ......... C=1.0, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# [CV] ......... C=1.0, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# [CV] ......... C=1.0, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=1.0, penalty=l1, solver=sag ...................................
# ...
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.471, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.506, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.477, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.581, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.488, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.535, total=   0.1s
# [CV] C=0.1, penalty=l2, solver=saga ..................................
# [CV] ...... C=0.1, penalty=l2, solver=saga, score=0.547, total=   0.1s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=newton-cg ............................
# [CV] .. C=0.01, penalty=l1, solver=newton-cg, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=lbfgs ................................
# [CV] ...... C=0.01, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.529, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.540, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.437, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.586, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.558, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.523, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=liblinear ............................
# [CV]  C=0.01, penalty=l1, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=sag ..................................
# [CV] ........ C=0.01, penalty=l1, solver=sag, score=nan, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.517, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.575, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.483, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.547, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.558, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.523, total=   0.0s
# [CV] C=0.01, penalty=l1, solver=saga .................................
# [CV] ..... C=0.01, penalty=l1, solver=saga, score=0.558, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.563, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.552, total=   0.1s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.448, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.500, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=newton-cg ............................
# [CV]  C=0.01, penalty=l2, solver=newton-cg, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.563, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.448, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.500, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=lbfgs ................................
# [CV] .... C=0.01, penalty=l2, solver=lbfgs, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.506, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.586, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.448, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.540, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.523, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.558, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.488, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.500, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=liblinear ............................
# [CV]  C=0.01, penalty=l2, solver=liblinear, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.563, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.448, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.500, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=sag ..................................
# [CV] ...... C=0.01, penalty=l2, solver=sag, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.563, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.448, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.552, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.535, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.581, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.500, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.512, total=   0.0s
# [CV] C=0.01, penalty=l2, solver=saga .................................
# [CV] ..... C=0.01, penalty=l2, solver=saga, score=0.581, total=   0.0s
# {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# ----------------------------------------------------------------------------------------------------
# LogisticRegression(C=0.1, penalty='l1', solver='saga')
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49       111
#            1       0.53      0.82      0.64       169
#            2       0.00      0.00      0.00        91
#
#     accuracy                           0.52       371
#    macro avg       0.34      0.43      0.38       371
# weighted avg       0.39      0.52      0.44       371
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:   22.3s finished

# %% [markdown]
# # DT

# %%
# parameter_grid ={'criterion' : ['gini', 'entropy'],
# 'max_depth' :range(1,12),
# 'random_state':[0, 1, 2, 3, 4, 5, 10, 15,20,35,50],
# 'min_samples_split':range(1,10),
# 'min_samples_leaf': range(1,6),
# }    


# dt_Model = DecisionTreeClassifier()
# dt_Grid = GridSearchCV(dt_Model,param_grid=parameter_grid,cv=10,verbose=1,n_jobs=-1)
# dt_Grid.fit(X_train, Y_train)
# print(dt_Grid.best_params_)
# print("-" * 100)
# print(dt_Grid.best_estimator_)
# print("-" * 100)

# Y_rf = dt_Grid.predict(X_test)
# Z=classification_report(Y_test, Y_rf)
# print(Z)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 10 folds for each of 10890 candidates, totalling 108900 fits
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1840 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 5184 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 8704 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 12304 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 16704 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21904 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 27904 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 33664 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 38152 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 42352 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 46952 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 51952 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 59912 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 71152 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 77352 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 83952 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 90200 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 96656 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 104456 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 108885 out of 108900 | elapsed: 15.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 108900 out of 108900 | elapsed: 15.7min finished
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 0}
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=0)
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.49      0.44      0.46       111
#            1       0.51      0.81      0.62       169
#            2       0.00      0.00      0.00        91
#
#     accuracy                           0.50       371
#    macro avg       0.33      0.42      0.36       371
# weighted avg       0.38      0.50      0.42       371

# %% [markdown]
# # RF

# %%
# # Number of trees in random forest
# n_estimators = [100, 300, 500, 800, 1200]
# # Number of features to consider at every split
# max_features = ['auto', 'log2']
# # Maximum number of levels in tree
# max_depth = [5, 8, 15, 25, 30]
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5, 10, 15, 100]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2, 5, 10]
# # Method of selecting samples for training each tree
# bootstrap = [True, False]


# param_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
#                'max_depth': max_depth,
#                'min_samples_split': min_samples_split,
#                'min_samples_leaf': min_samples_leaf,
#                'bootstrap': bootstrap}

# rf_Model = RandomForestClassifier()
# rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = -1)
# rf_Grid.fit(X_train, Y_train)
# print(rf_Grid.best_params_)
# print("-" * 100)
# print(rf_Grid.best_estimator_)
# print("-" * 100)

# Y_rf = rf_Grid.predict(X_test)
# y=classification_report(Y_test, Y_rf)
# print(y)
# Out:
# Fitting 3 folds for each of 2000 candidates, totalling 6000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 3265 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done 4885 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=-1)]: Done 5816 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=-1)]: Done 6000 out of 6000 | elapsed: 32.4min finished
# {'bootstrap': True, 'max_depth': 25, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier(max_depth=25, min_samples_leaf=2)
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.56      0.40      0.46       111
#            1       0.51      0.85      0.64       169
#            2       0.27      0.03      0.06        91
#
#     accuracy                           0.51       371
#    macro avg       0.45      0.43      0.39       371
# weighted avg       0.47      0.51      0.44       371

# %% [markdown]
# # SVC

# %%
param_grid = {'C': [1, 10, 100, 1000],
              'gamma': [1,0.001, 0.0001],'kernel': ['rbf', 'poly', 'sigmoid']}

grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train,Y_train)

print(grid.best_params_)
print("-" * 100)
print(grid.best_estimator_)
print("-" * 100)

Y_rf = grid.predict(X_test)
y=classification_report(Y_test, Y_rf)
print(y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........................ C=1, gamma=1, kernel=poly, total=   0.1s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........................ C=1, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........................ C=1, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........................ C=1, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........................ C=1, gamma=1, kernel=poly, total=   0.1s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ..................... C=1, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ..................... C=1, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ..................... C=1, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ..................... C=1, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ..................... C=1, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] .................... C=1, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] .................... C=1, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] .................... C=1, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] .................... C=1, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] .................... C=1, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=1, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=1, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=1, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=1, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=1, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=poly ..................................
# [CV] ................... C=1, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=poly ..................................
# [CV] ................... C=1, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=poly ..................................
# [CV] ................... C=1, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=poly ..................................
# [CV] ................... C=1, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=poly ..................................
# [CV] ................... C=1, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=sigmoid ...............................
# [CV] ................ C=1, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=sigmoid ...............................
# [CV] ................ C=1, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=sigmoid ...............................
# [CV] ................ C=1, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=sigmoid ...............................
# [CV] ................ C=1, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=sigmoid ...............................
# [CV] ................ C=1, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] ....................... C=10, gamma=1, kernel=poly, total=   0.0s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] ....................... C=10, gamma=1, kernel=poly, total=   0.0s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] ....................... C=10, gamma=1, kernel=poly, total=   0.1s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] ....................... C=10, gamma=1, kernel=poly, total=   0.0s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] ....................... C=10, gamma=1, kernel=poly, total=   0.1s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] .................... C=10, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] .................... C=10, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] .................... C=10, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] .................... C=10, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] .................... C=10, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ................... C=10, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ................... C=10, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ................... C=10, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ................... C=10, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ................... C=10, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] .................. C=10, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] .................. C=10, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] .................. C=10, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] .................. C=10, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] .................. C=10, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] ............... C=10, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] ............... C=10, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] ............... C=10, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] ............... C=10, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] ............... C=10, gamma=0.0001, kernel=sigmoid, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ...................... C=100, gamma=1, kernel=poly, total=   0.1s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ...................... C=100, gamma=1, kernel=poly, total=   0.1s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ...................... C=100, gamma=1, kernel=poly, total=   0.0s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ...................... C=100, gamma=1, kernel=poly, total=   0.0s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ...................... C=100, gamma=1, kernel=poly, total=   0.1s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ................... C=100, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ................... C=100, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ................... C=100, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ................... C=100, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ................... C=100, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] .................. C=100, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] .................. C=100, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] .................. C=100, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] .................. C=100, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] .................. C=100, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] ............... C=100, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] ............... C=100, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] ............... C=100, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] ............... C=100, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] ............... C=100, gamma=0.001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=poly ................................
# [CV] ................. C=100, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=poly ................................
# [CV] ................. C=100, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=poly ................................
# [CV] ................. C=100, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=poly ................................
# [CV] ................. C=100, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=poly ................................
# [CV] ................. C=100, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=sigmoid .............................
# [CV] .............. C=100, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=sigmoid .............................
# [CV] .............. C=100, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=sigmoid .............................
# [CV] .............. C=100, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=sigmoid .............................
# [CV] .............. C=100, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=sigmoid .............................
# [CV] .............. C=100, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=1, kernel=poly ....................................
# [CV] ..................... C=1000, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=1, kernel=poly ....................................
# [CV] ..................... C=1000, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=1, kernel=poly ....................................
# [CV] ..................... C=1000, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=1, kernel=poly ....................................
# [CV] ..................... C=1000, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=1, kernel=poly ....................................
# [CV] ..................... C=1000, gamma=1, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=1, kernel=sigmoid .................................
# [CV] .................. C=1000, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=1, kernel=sigmoid .................................
# [CV] .................. C=1000, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=1, kernel=sigmoid .................................
# [CV] .................. C=1000, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=1, kernel=sigmoid .................................
# [CV] .................. C=1000, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=1, kernel=sigmoid .................................
# [CV] .................. C=1000, gamma=1, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=poly ................................
# [CV] ................. C=1000, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=poly ................................
# [CV] ................. C=1000, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=poly ................................
# [CV] ................. C=1000, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=poly ................................
# [CV] ................. C=1000, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=poly ................................
# [CV] ................. C=1000, gamma=0.001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=sigmoid .............................
# [CV] .............. C=1000, gamma=0.001, kernel=sigmoid, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=sigmoid .............................
# [CV] .............. C=1000, gamma=0.001, kernel=sigmoid, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=sigmoid .............................
# [CV] .............. C=1000, gamma=0.001, kernel=sigmoid, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=sigmoid .............................
# [CV] .............. C=1000, gamma=0.001, kernel=sigmoid, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=sigmoid .............................
# [CV] .............. C=1000, gamma=0.001, kernel=sigmoid, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] ................. C=1000, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] ................. C=1000, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] ................. C=1000, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] ................. C=1000, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] ................. C=1000, gamma=0.0001, kernel=rbf, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=poly ...............................
# [CV] ................ C=1000, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=poly ...............................
# [CV] ................ C=1000, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=poly ...............................
# [CV] ................ C=1000, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=poly ...............................
# [CV] ................ C=1000, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=poly ...............................
# [CV] ................ C=1000, gamma=0.0001, kernel=poly, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=sigmoid ............................
# [CV] ............. C=1000, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=sigmoid ............................
# [CV] ............. C=1000, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=sigmoid ............................
# [CV] ............. C=1000, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=sigmoid ............................
# [CV] ............. C=1000, gamma=0.0001, kernel=sigmoid, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=sigmoid ............................
# [CV] ............. C=1000, gamma=0.0001, kernel=sigmoid, total=   0.0s
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# ----------------------------------------------------------------------------------------------------
# SVC(C=1, gamma=0.001)
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.55      0.44      0.49       111
#            1       0.53      0.88      0.66       169
#            2       0.00      0.00      0.00        91
#
#     accuracy                           0.53       371
#    macro avg       0.36      0.44      0.38       371
# weighted avg       0.41      0.53      0.45       371
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    6.7s finished

# %% [markdown]
# # Tuning

# %%
gs_NB_Grid = GaussianNB()
gs_NB_Grid=GaussianNB(var_smoothing=0.0009)
NBOpt = gs_NB_Grid.fit(X_train, Y_train)
Y_nb = NBOpt.predict(X_test)
F=classification_report(Y_test, Y_nb)
print(F)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.36      0.43       111
#            1       0.52      0.82      0.64       169
#            2       0.30      0.10      0.15        91
#
#     accuracy                           0.50       371
#    macro avg       0.45      0.43      0.40       371
# weighted avg       0.47      0.50      0.45       371

# %%
gs_LR = LogisticRegression()
gs_LR = LogisticRegression(C=100, penalty='l1', solver='saga')                                
LROpt = gs_LR.fit(X_train, Y_train)
Y_lr = LROpt.predict(X_test)
Z=classification_report(Y_test, Y_lr)
print(Z)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.46      0.48       111
#            1       0.53      0.77      0.63       169
#            2       0.23      0.07      0.10        91
#
#     accuracy                           0.50       371
#    macro avg       0.42      0.43      0.40       371
# weighted avg       0.45      0.50      0.46       371

# %%
dt_Grid = DecisionTreeClassifier()
dt_Grid = DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_leaf=1, min_samples_split=2,random_state=0)                                
dtOpt = dt_Grid.fit(X_train, Y_train)
Y_dt = dtOpt.predict(X_test)
p=classification_report(Y_test, Y_dt)
print(p)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.29      0.36       111
#            1       0.51      0.79      0.62       169
#            2       0.30      0.14      0.19        91
#
#     accuracy                           0.48       371
#    macro avg       0.43      0.41      0.39       371
# weighted avg       0.45      0.48      0.44       371

# %%
rf_Grid = RandomForestClassifier(random_state = 1, max_depth = 16,bootstrap=True,max_features='auto',     
                        n_estimators = 1200, min_samples_split = 2, min_samples_leaf = 1)
                                   
RFlOpt = rf_Grid.fit(X_train, Y_train)
Y_rf = RFlOpt.predict(X_test)
y=classification_report(Y_test, Y_rf)
print(y)

# %%
grid = SVC(C = 10,gamma=0.01,kernel='rbf')
SVCOpt = grid.fit(X_train,Y_train)
Y_sv = SVCOpt.predict(X_test)
d=classification_report(Y_test, Y_sv)
print(d)

# %% [markdown]
# # Features Importance

# %%
importance = abs(LROpt.coef_[0])

list_1 = []
list_2 = []
for i,j in zip(importance,X.columns):
    list_1.append(str(j))
    list_2.append(i)
    
df_name = pd.DataFrame(list_1,columns=["Features"])
df_number = pd.DataFrame(list_2,columns=["Importances"])

df_ranking = pd.concat([df_name, df_number], axis=1)
df_final = df_ranking.sort_values("Importances",ascending=False).reset_index(drop=True)
df_final.Features = df_final.Features.astype(str)
f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x="Importances", y="Features", data=df_final)

# %% [markdown]
# # predict Final Season Standing

# %%
raw_data_20 = pd.read_csv(r"Seasons\seasons19-20.csv")
Y_test=raw_data_20['FTR']
v = pd.read_csv(r"Tables\Book2.csv")

gs_LR = LogisticRegression()
gs_LR = LogisticRegression(C=100, penalty='l1', solver='saga')                                
LROpt = gs_LR.fit(X_train, Y_train)

Y_lr = LROpt.predict(v)
print("-" * 100)
print(classification_report(Y_test, Y_lr))

# %%
Y_rf=pd.DataFrame(Y_lr)
season_predict=v[['home_encoded','away_encoded']]
season_predict['FTR']=Y_rf.to_numpy()
season_predict.loc[(season_predict['FTR']==1),'hp']=3
season_predict.loc[(season_predict['FTR']==2),'hp']=1
season_predict.loc[(season_predict['FTR']==0),'hp']=0


season_predict.loc[(season_predict['FTR']==0),'ap']=3
season_predict.loc[(season_predict['FTR']==2),'ap']=1
season_predict.loc[(season_predict['FTR']==1),'ap']=0

season_predict


def homeresults(team,df):
    teamsum=0
    for i in range(len(df)):
        if team == df.loc[i,['home_encoded']].values[0]:
            teamsum+=df.loc[i,['hp']].values[0]
    return teamsum

def awayresults(team,df):
    teamsum=0
    for i in range(len(df)):
        if team == df.loc[i,['away_encoded']].values[0]:
            teamsum+=df.loc[i,['ap']].values[0]
    return teamsum

tally={}
for i in pd.unique(season_predict['home_encoded']).tolist():
    for name,team in home_encoded_mapping.items():
        if team == i:    
            total=0
            total+=homeresults(i,season_predict)
            total+=awayresults(i,season_predict)
            tally[name]=total
    
var=sorted(tally.items(),key=lambda x: x[1],reverse=True)
var

# %% [markdown]
#  # Predict FTHG -best predictor

# %%
X=data.drop(['Date','FTHG', 'FTAG', 'HTHG','HTAG', 'HS',
             'AS', 'HST', 'AST', 'HC', 'AC', 'HTR', 'FTR'],axis=1)

X.fillna(0,inplace=True)
y=data['FTHG']# change for want is wanted

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=35).fit(X_scaled)
X_pca = pca.transform(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)')
plt.show()
# X.to_csv('X-20.csv',index=False)
X_train, X_test, Y_train, Y_test = train_test_split(X_pca, y,test_size=0.3,random_state=1,shuffle=None)

# %%
lr_classifier = LogisticRegression()
param_lr = {"C":[100, 10, 1.0, 0.1, 0.01], "penalty":["l1","l2"],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
             }


gs_LR = LogisticRegression()
gs_LR = GridSearchCV(lr_classifier, param_grid=param_lr, refit = True, verbose = 3, cv=10) 
gs_LR.fit(X_train, Y_train)
print(gs_LR.best_params_)
print("-" * 100)
print(gs_LR.best_estimator_)
print("-" * 100)
print(gs_LR.best_score_)
print("-" * 100)

Y_lr = gs_LR.predict(X_test)
Z=classification_report(Y_test, Y_lr)
print(Z)

# %%
gs_LR = LogisticRegression()
gs_LR = LogisticRegression(C=10, penalty='l1', solver='saga')                                
LROpt = gs_LR.fit(X_train, Y_train)
Y_lr = LROpt.predict(X_test)
Z=classification_report(Y_test, Y_lr)
print(Z)

# %%
def confusion_matrix_heatmap(testTrue, testPred):
    """Function to plot a confusion matrix"""
    labels = list(set(testPred))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(testTrue, testPred, labels)
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=0)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="orange")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
confusion_matrix_heatmap(Y_test, Y_lr)
